# %%
# !pip install -q google-generativeai faiss-cpu pandas numpy tqdm streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 73.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 45.4 MB/s eta 0:00:00

# %%
# !pip install -q faiss-cpu

# %%
import os
import json
import zipfile
import pandas as pd
from tqdm import tqdm
import numpy as np
import faiss
import google.generativeai as genai

# %%
zip_path = "/content/mimic-iv-ext-direct-1.0.0.zip"
extract_path = "/content/mimic-iv-ext/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted to:", extract_path)
# Out:
# Dataset extracted to: /content/mimic-iv-ext/

# %%
for root, dirs, files in os.walk(extract_path):
    for f in files:
        if f.endswith(".json"):
            print(os.path.join(root, f))
# Out:
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Migraine/Migraine With Aura/._17676552-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Migraine/Migraine With Aura/._18427803-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Migraine/Migraine With Aura/._18805216-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Migraine/Migraine Without Aura/._17185323-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hypothyroidism/._11697485-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hypothyroidism/._14596661-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hypothyroidism/._13561991-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Thyroid Nodules/._16973388-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Thyroid Nodules/._18292099-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hyperthyroidism/._16471629-DS-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hyperthyroidism/._13746170-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hyperthyroidism/._13787731-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Hyperthyroidism/._16693380-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Thyroid Disease/Thyroiditis/._15973805-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Arrhythmogenic Right Ventricular Cardiomyopathy/._16683512-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Hypertrophic Cardiomyopathy/._15466684-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Hypertrophic Cardiomyopathy/._11901665-DS-24.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Dilated Cardiomyopathy/._13216060-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Dilated Cardiomyopathy/._17519144-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Dilated Cardiomyopathy/._17369619-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Dilated Cardiomyopathy/._18065146-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Restrictive Cardiomyopathy/._17067683-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Cardiomyopathy/Restrictive Cardiomyopathy/._18108905-DS-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._19182957-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._13607135-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._13573314-DS-34.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._13661098-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18905329-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18084435-DS-21.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18639999-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._16003661-DS-27.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18425773-DS-12.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._16512044-DS-19.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17796507-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18814172-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._15872905-DS-4.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17430704-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18296811-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._16277357-DS-15.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17430704-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._12302912-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18635756-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._14828954-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._11458370-DS-14.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._16330623-DS-12.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._16380225-DS-9.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._13290763-DS-20.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._13800231-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._19242928-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._14592188-DS-9.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._16276452-DS-8.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._14244305-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._13063258-DS-20.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17830445-DS-7.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17809917-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17762094-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._15696887-DS-14.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17483512-DS-17.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._18740413-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17755142-DS-15.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17762094-DS-27.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._14175995-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._17531182-DS-17.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastro-oesophageal Reflux Disease/._14632181-DS-18.json.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._11535902-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._11990712-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17132866-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17822063-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._12275216-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17842926-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._12806822-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17685057-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17505744-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17923616-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17539265-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._11859083-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17357689-DS-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17915457-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17399182-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17409962-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._12364675-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17509032-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17511292-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17753691-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._12808249-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17581064-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._12054012-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17105161-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._12137011-DS-27.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17577620-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._11992836-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/NSTEMI/._17183564-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._12238650-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._16137568-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._15314906-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._15402809-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._13007301-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._11514847-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._13288722-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._11528474-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._15838052-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._11801858-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._12392100-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._16250904-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._13696506-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._15100941-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/STEMI/._15379632-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14895513-DS-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14167883-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._13136218-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._12445879-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._11706286-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._13000968-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._12261639-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._11985139-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._15171397-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._11657791-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._12789116-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14207519-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._12924595-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14511469-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14946203-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._11677801-DS-34.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14879291-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14876183-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14512858-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._14301754-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._11677801-DS-33.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Acute Coronary Syndrome/UA/._11959580-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._15247348-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._13971464-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._11878388-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._15616719-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._16620644-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._14545508-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Upper Gastrointestinal Bleeding/._17028519-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Primary Progressive Multiple Sclerosis/._12994754-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Primary Progressive Multiple Sclerosis/._13036011-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12331699-DS-2311.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._14789229-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._11981102-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._11475935-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12994754-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12979013-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._14676772-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._15353648-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._13849116-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._13901573-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._15226178-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12546487-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._15116755-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12108816-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12994754-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._15333597-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12546487-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12594529-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._14784368-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._13043422-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12331699-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Relapsing-Remitting Multiple Sclerosis/._12172828-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Secondary Progressive Multiple Sclerosis/._12846155-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Secondary Progressive Multiple Sclerosis/._13901573-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Multiple Sclerosis/Secondary Progressive Multiple Sclerosis/._12331699-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hyperlipidemia/._13591813-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hyperlipidemia/._11750185-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._14110132-DS-24.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._extra-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._extra-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._19103590-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._16147199-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._11620099-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._15824797-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._16752897-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._19441625-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._19313611-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._extra-1.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._15824797-DS-151.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._17414827-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._16956657-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._13503429-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Bacterial Pneumonia/._13504185-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Viral Pneumonia/._13316652-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Viral Pneumonia/._15585852-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Viral Pneumonia/._17763117-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pneumonia/Viral Pneumonia/._15782217-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Persistent Atrial Fibrillation/._15008480-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Persistent Atrial Fibrillation/._16368173-DS-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._16089043-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._16123634-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._14647136-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._17003536-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._13492756-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._17943628-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._19489502-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Atrial Fibrillation/Paroxysmal Atrial Fibrillation/._12116250-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._12342173-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._15166831-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._14994182-DS-36.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._14818191-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._17187522-DS-41.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._18923313-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._18735835-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._17808538-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._17436407-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._14725771-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._17468815-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._18096479-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._18656167-DS-64.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._18591903-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._12206678-DS-90.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._13892051-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._11482871-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._13227028-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/COPD/._11655904-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._18217759-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11416084-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11416397-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11416084-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._14936659-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._17960078-DS-62.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._17665357-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._17604315-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._13127922-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11737430-DS-29.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._17035408-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._18528299-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._16543302-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._12828031-DS-27.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._12006801-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._16617903-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._19141642-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._13826272-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._15185281-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._15874317-DS-28.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._19435301-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11962352-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11416084-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._18944079-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._14944299-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._15706386-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._18026938-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._13313134-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._13092414-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._18732758-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._11501987-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Hypertension/._12551014-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Congenital Adrenal Hyperplasia/._13281479-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Congenital Adrenal Hyperplasia/._13281479-DS-1912.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Congenital Adrenal Hyperplasia/._16003330-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._12544251-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._18136887-DS-67.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._18136887-DS-78.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._12468016-DS-60.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._12468016-DS-6000.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._16003330-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._11698212-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._16379709-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._12964119-DS-3555.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Secondary Adrenal Insufficiency/._12964119-DS-35.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._19102476-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._18136887-DS-67.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._18136887-DS-78.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._17076162-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._17076162-DS-1222.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._19102476-DS-1777.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Adrenal Insufficiency/Primary Adrenal Insufficiency/._16379709-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Massive PE/._17850733-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Massive PE/._15917563-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._15276169-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._12759698-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._11580528-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._15427589-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._13738109-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._16856084-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._15418476-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._18895551-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._12341559-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._17087118-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._15190301-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._18130160-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._12763117-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._11590913-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._16261765-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._16823547-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._13327415-DS-25.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._16502049-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._17440689-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._13420510-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Low-risk PE/._12831732-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._12554980-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._15536737-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._18865972-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._16658982-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._18344499-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._15686498-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._12533087-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._12301488-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._16179881-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._12964739-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._16061224-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pulmonary Embolism/Submassive PE/._12519803-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._12709553-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._13562354-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._11573828-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._12688174-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._17779332-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._15430683-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._14633589-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._19135392-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._13246627-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._18987116-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Macroadenoma/._19001641-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Pituitary Disease/Pituitary Microadenoma/._18144647-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Cough-Variant Asthma/._17892612-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/COPD Asthma/._11707288-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/COPD Asthma/._15798127-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Severe Asthma Exacerbation/._18192172-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Severe Asthma Exacerbation/._19219717-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Severe Asthma Exacerbation/._17567631-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Severe Asthma Exacerbation/._16105600-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Asthma/._13885966-DS-24.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Asthma/._18681184-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Non-Allergic Asthma/._18699864-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Non-Allergic Asthma/._18153872-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Non-Allergic Asthma/._17832311-DS-23.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Asthma/Allergic Asthma/._11897861-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._18945414-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._11389640-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._17745031-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._17784861-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._17776030-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._19329252-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._11546219-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Atrophic Gastritis/._18001923-DS-35.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Non-atrophic Gastritis/._18945414-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Non-atrophic Gastritis/._18996244-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Non-atrophic Gastritis/._17540771-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Non-atrophic Gastritis/._12340605-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Chronic Non-atrophic Gastritis/._17776030-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._11541457-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._11389640-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._19444258-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._19341663-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._12441564-DS-18.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._18473921-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._17887687-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._18519555-DS-2.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._11589948-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._11908878-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._18151206-DS-22.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._19542790-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._11520879-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/._18001923-DS-35.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._17277521-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._11999108-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._14795613-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._15898350-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._12312333-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._12109697-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._17739375-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._14238472-DS-8.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._12134520-DS-16.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/._14940781-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/._15590996-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/._15793371-DS-13.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/._13730220-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/._13187640-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/._13691292-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/._12381874-DS-9.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/._12280090-DS-12.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/._16314601-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/._12788473-DS-11.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/._12909121-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Epilepsy/._14690121-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Epilepsy/._14535113-DS-34.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Epilepsy/._14070294-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._19210913-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._19281526-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._14920657-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._14210167-DS-15.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._13040569-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._13642689-DS-5.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._16045669-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._16310435-DS-20.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/._14210167-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/._18066087-DS-7.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/._13040569-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/._18252585-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/._18297404-DS-6.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/._17304892-DS-10.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._17352394-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._11459120-DS-27.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._18870530-DS-17.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._17176117-DS-4.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._11691034-DS-3.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._18536618-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._18548050-DS-21.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._17319103-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._17316016-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._11422357-DS-14.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._17205507-DS-19.json
# /content/mimic-iv-ext/__MACOSX/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/._18888515-DS-22.json
# ...
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Gastritis/Acute Gastritis/11389640-DS-16.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/15898350-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/17277521-DS-10.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/11999108-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/14238472-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/12134520-DS-16.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/14795613-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/12109697-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/14940781-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/17739375-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Alzheimer/12312333-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/15590996-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/13691292-DS-3.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/13730220-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/13187640-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Tuberculosis/15793371-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/12788473-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/12381874-DS-9.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/12280090-DS-12.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/12909121-DS-6.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Non-epileptic Seizure/16314601-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Epilepsy/14070294-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Epilepsy/14690121-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Epilepsy/Epilepsy/14535113-DS-34.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/19281526-DS-10.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/14210167-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/16045669-DS-3.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/19210913-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/13040569-DS-4.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/16310435-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/14210167-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/14920657-DS-6.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type B Aortic Dissection/13642689-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/18066087-DS-7.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/18297404-DS-6.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/17304892-DS-10.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/13040569-DS-4.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Aortic Dissection/Type A Aortic Dissection/18252585-DS-3.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17191670-DS-18.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18718424-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18902344-DS-47.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/19058546-DS-16.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11459120-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18740324-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/19019784-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17205507-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11607177-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11422357-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11465548-DS-9.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18853045-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17322218-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18647733-DS-7.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18870530-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18962557-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18834270-DS-10.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/19158991-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11459120-DS-27.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11459120-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17167392-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11696880-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18581055-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/19043930-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18624255-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18853045-DS-16.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/19042495-DS-22.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11386787-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18729731-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17316016-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18536618-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11459120-DS-16.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11459120-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17319103-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17123250-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17176117-DS-4.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11691034-DS-3.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17304513-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11475050-DS-27.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17165207-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17244619-DS-41.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17277045-DS-9.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18888515-DS-22.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17352394-DS-4.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18548050-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/11868165-DS-24.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17243592-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17143325-DS-23.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/19213219-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18606160-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/17196497-DS-3.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Heart Failure/18693746-DS-10.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/15039042-DS-12.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/12190635-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/19155318-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/12086937-DS-2.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/stroke_sample1.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/14189463-DS-10.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/14588438-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/16646033-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/15100095-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/13256522-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/19441468-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/14651148-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/14112332-DS-18.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/11408894-DS-2.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Hemorrhagic Stroke/15612258-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11790430-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/18833652-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11452808-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11896216-DS-7.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11882869-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/19038331-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/19227459-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11853860-DS-23.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11800237-DS-4.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/11875736-DS-6.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/14538785-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/16172945-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Stroke/Ischemic Stroke/18908844-DS-9.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/19142711-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/13839174-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/17517983-DS-78.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/17523255-DS-7.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/17517983-DS-49.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/15131866-DS-6.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type I Diabetes/12379918-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type II Diabetes/13154769-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type II Diabetes/13918653-DS-4.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type II Diabetes/13180007-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type II Diabetes/13301812-DS-3.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type II Diabetes/13050690-DS-6.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Diabetes/Type II Diabetes/13223220-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/16714362-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/11993263-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/19163991-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/12484285-DS-2.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/19505167-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/12021335-DS-5.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/14041557-DS-15.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/11797021-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/11416792-DS-14.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/17868682-DS-81.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/19458321-DS-18.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/14925002-DS-9.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/12680418-DS-19.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/14564935-DS-18.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/16714362-DS-1533.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/17590576-DS-20.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/17910930-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/17676595-DS-13.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/17868682-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Gastric Ulcers/15658321-DS-8.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/11833885-DS-11.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/13688835-DS-12.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/16882192-DS-33.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/19505167-DS-17.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/15177004-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/13188037-DS-21.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/15177004-DS-211.json
# /content/mimic-iv-ext/mimic-iv-ext-direct-1.0.0/Finished/Peptic Ulcer Disease/Duodenal Ulcers/17910930-DS-11.json

# %%
documents = []

for root, _, files in os.walk(extract_path):
    for f in files:
        if f.endswith(".json"):
            file_path = os.path.join(root, f)
            with open(file_path, "r") as file:
                try:
                    data = json.load(file)
                except:
                    continue

                # Add each JSON record as a document
                if isinstance(data, list):
                    for record in data:
                        # Convert JSON to readable text
                        readable_text = json.dumps(record, indent=0).replace('\n', ' ')
                        documents.append(readable_text)
                else:
                    readable_text = json.dumps(data, indent=0).replace('\n', ' ')
                    documents.append(readable_text)

print("Total Documents Loaded:", len(documents))

# Show sample without breaking loop
if documents:
    print("\n📄 Sample document (first 200 chars):")
    print(documents[0][:200] + "...")
# Out:
# Total Documents Loaded: 511
#
# 📄 Sample document (first 200 chars):
# { "Migraine With Aura$Intermedia_3": { "Difficulty expressing language may be associated with migraine, especially when migraine is accompanied by neurological symptoms$Cause_1": { "Difficulty produci...

# %%
print("\n🔧 Cleaning JSON documents for better readability...")

def clean_json_document(doc):
    """Clean JSON documents to remove clutter and improve readability"""
    import re

    if isinstance(doc, str):
        # Remove excessive JSON formatting
        doc = re.sub(r'\s*\{\s*"', '"', doc)
        doc = re.sub(r'"\s*:\s*\{', ': ', doc)
        doc = re.sub(r'\}\s*,?\s*\}', '}', doc)
        doc = re.sub(r'\$[A-Za-z0-9_]+', '', doc)  # Remove $Intermedia_5 etc
        doc = re.sub(r'\*?\$Input\d+', '', doc)
        doc = re.sub(r'([A-Z][a-z]+)\$\w+', r'\1', doc)

        # Keep it readable length
        if len(doc) > 800:
            doc = doc[:800] + "..."

    return doc

# Apply cleaning
documents = [clean_json_document(doc) for doc in documents]

print(f"✅ Documents cleaned! Now have {len(documents)} documents")
print("\n📄 Before cleaning preview:")
print("Raw: Migraine With Aura$Intermedia_3...")
print("\n📄 After cleaning preview:")
print(documents[0][:200] + "...")
# Out:
# 🔧 Cleaning JSON documents for better readability...
# ✅ Documents cleaned! Now have 511 documents
#
# 📄 Before cleaning preview:
# Raw: Migraine With Aura$Intermedia_3...
#
# 📄 After cleaning preview:
# "Migraine With Aura":"Difficulty expressing language may be associated with migraine, especially when migraine is accompanied by neurological symptoms":"Difficulty producing speech: }, "Persistent hea...

# %%
# !pip install -q sentence-transformers

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')  # 80MB, downloads in 5s

embeddings = model.encode(documents, batch_size=32, show_progress_bar=True)
print("First document embedding (first 10 dimensions):", embeddings[0][:10])
print(f"✅ Done! Shape: {embeddings.shape}")
# Out:
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# First document embedding (first 10 dimensions): [ 0.05549387 -0.0644675   0.04017159  0.03721104 -0.05382313  0.06045882
#   0.12579285  0.0084793   0.00986471 -0.02953939]
# ✅ Done! Shape: (511, 384)

# %%
import faiss
import numpy as np

# Convert to float32 FIRST
embeddings_f32 = embeddings.astype('float32')  # ⬅️ CRITICAL

d = embeddings_f32.shape[1]   # dimension
index = faiss.IndexFlatL2(d)
index.add(embeddings_f32)     # ⬅️ Use float32 version

print("✅ FAISS index created with", index.ntotal, "documents of dimension", d)

# Test it works
test_query = "migraine headache"
test_emb = model.encode([test_query]).astype('float32')
distances, indices = index.search(test_emb, 3)

print(f"\n🔍 Test query: '{test_query}'")
print(f"Retrieved documents: {indices[0]}")
print(f"Unique documents: {len(set(indices[0]))}")
# Out:
# ✅ FAISS index created with 511 documents of dimension 384
#
# 🔍 Test query: 'migraine headache'
# Retrieved documents: [1 0 3]
# Unique documents: 3

# %%
def retrieve_with_scores(query, top_k=5):
    """Retrieve documents with similarity scores"""
    q_emb = model.encode([query]).astype('float32')
    distances, idx = index.search(q_emb, top_k)

    # Print what happened during retrieval
    print(f"Query: '{query}'")
    print(f"Query embedding shape: {q_emb.shape}")
    print(f"Retrieved indices: {idx[0]}")
    print(f"Distances: {distances[0]}")

    results = []
    for i, (doc_idx, distance) in enumerate(zip(idx[0], distances[0])):
        if doc_idx != -1:  # ⬅️ ADD THIS LINE to skip invalid indices
            similarity = 1 / (1 + distance)  # Simple conversion
            results.append({
                'rank': i+1,
                'document': documents[doc_idx],
                'similarity': round(float(similarity), 4)
            })

    print(f"Top result similarity score: {results[0]['similarity'] if results else 'No results'}")
    return results

# %%
genai.configure(api_key="AIzaSyCxL29qRgP96gaWKCU-p-yvFKgvq2J52gM")

# %%
generation_model = genai.GenerativeModel("gemini-2.5-flash")

def rag_answer_smart(query, top_k=3):
    """Smart RAG: Uses patient records when relevant, supplements with general knowledge"""

    print(f"\n{'='*60}")
    print(f"🤖 SMART RAG Pipeline Started")
    print(f"📝 Query: '{query}'")
    print(f"🔍 Retrieving top {top_k} most relevant documents...")

    # 1. Retrieve documents with similarity scores
    retrieved = retrieve_with_scores(query, top_k=top_k)

    print(f"📄 Documents retrieved: {len(retrieved)}")
    if retrieved:
        print(f"📊 Highest similarity: {retrieved[0]['similarity']:.4f}")
        print(f"📊 Lowest similarity: {retrieved[-1]['similarity']:.4f}")

    # 2. Check relevance threshold
    all_low_relevance = all(r['similarity'] < 0.3 for r in retrieved)

    if all_low_relevance and retrieved:
        print(f"⚠️  All documents have low relevance (< 0.3) - using general knowledge mode")
        # GENERAL KNOWLEDGE MODE
        prompt = f"""MEDICAL QUESTION: {query}

You are a medical expert. Provide accurate, evidence-based information.
Follow these guidelines:
1. Be comprehensive and factual
2. Cite sources/guidelines if applicable (e.g., ICHD-3, ACC/AHA)
3. Include diagnostic criteria, symptoms, treatments as relevant
4. Use clear formatting with bullet points or numbered lists
5. If query mentions specific patient terms, explain them generally

PROFESSIONAL ANSWER:"""

        mode = "general_knowledge"

    else:
        # RAG + SUPPLEMENT MODE
        print(f"✅ Found relevant documents - using RAG with supplementation")

        # Format context with relevance scores
        ctx_formatted = []
        for i, r in enumerate(retrieved):
            # Show relevance indicator
            relevance_indicator = "🟢" if r['similarity'] > 0.4 else "🟡" if r['similarity'] > 0.3 else "🔴"
            doc_preview = r['document'][:500] + "..." if len(r['document']) > 500 else r['document']
            ctx_formatted.append(f"{relevance_indicator} [Document {i+1}, Relevance: {r['similarity']:.3f}]:\n{doc_preview}")

        context_str = "\n\n".join(ctx_formatted)

        print(f"📋 Context prepared: {len(ctx_formatted)} documents")
        print(f"📏 Total context length: {len(context_str)} characters")

        prompt = f"""You are a medical analyst assistant. Analyze the query and provide the best answer.

USER QUESTION: {query}

RELEVANT PATIENT RECORDS (Most relevant first):
{context_str}

INSTRUCTIONS:
1. **FIRST** check if the patient records contain relevant information
2. If records ARE relevant:
   - Start with "Based on patient records:"
   - Extract and summarize information from the records
   - Cite specific documents (Document 1, Document 2, etc.)
3. If records ARE NOT sufficient:
   - Acknowledge what was found in records
   - Add "Supplementing with general medical knowledge:"
   - Provide comprehensive information from general knowledge
4. If records are completely irrelevant to the query:
   - State "No relevant patient records found"
   - Provide a complete general medical answer
5. Always maintain medical accuracy and clarity

STRUCTURED ANSWER:"""

        mode = "rag_with_supplement"

    print(f"💭 Generating response ({mode})...")

    try:
        response = generation_model.generate_content(prompt)
        print(f"✅ Response generated successfully ({len(response.text)} characters)")
        print(f"{'='*60}\n")

        # Add mode info to return
        return response.text, retrieved, mode

    except Exception as e:
        print(f"❌ Error: {str(e)}")
        print(f"{'='*60}\n")
        return f"Error: {str(e)}", retrieved, "error"

# %%
# Test with your migraine query
query = "What are the diagnostic criteria for Migraine With Aura?"
answer, sources, mode = rag_answer_smart(query)

print("ANSWER:")
print(answer)

if sources:
    print(f"\nBased on {len(sources)} patient records")
else:
    print("\n⚠️ No relevant records found - using general medical knowledge")
# Out:
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What are the diagnostic criteria for Migraine With Aura?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What are the diagnostic criteria for Migraine With Aura?'
# Query embedding shape: (1, 384)
# Retrieved indices: [0 2 3]
# Distances: [0.5405734  0.6228178  0.62445223]
# Top result similarity score: 0.6491
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.6491
# 📊 Lowest similarity: 0.6156
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (1740 characters)
# ============================================================
#
# ANSWER:
# Based on patient records:
# The records indicate that Migraine With Aura can be associated with "Difficulty expressing language," "Difficulty producing speech," and "Reduced speech output," which may present as impaired or altered quality of speech alongside persistent headaches (Document 1). Visual symptoms like "Blurred vision" or other "visual abnormalities" affecting one or both eyes, also referred to as a "visual aura," can precede or occur during an attack, sometimes followed by an occipital headache (Document 2).
#
# Supplementing with general medical knowledge:
# The provided patient records describe symptoms associated with Migraine With Aura but do not provide the formal diagnostic criteria. According to the International Classification of Headache Disorders, 3rd edition (ICHD-3), the diagnostic criteria for Migraine With Aura are:
#
# A. At least two attacks fulfilling criteria B and C.
# B. Aura consisting of at least one of the following fully reversible symptoms:
#     1. Visual symptoms (e.g., flickering lights, spots, lines, or partial loss of vision)
#     2. Sensory symptoms (e.g., tingling, numbness)
#     3. Speech and/or language symptoms (e.g., aphasia, dysphasia)
#     4. Motor weakness
#     5. Brainstem symptoms (e.g., vertigo, tinnitus, diplopia)
#     6. Retinal symptoms (e.g., monocular visual disturbance)
# C. At least two of the following four characteristics:
#     1. At least one aura symptom spreads gradually over ≥5 minutes, and/or two or more symptoms occur in succession.
#     2. Each individual aura symptom lasts 5-60 minutes.
#     3. At least one aura symptom is unilateral.
#     4. The aura is accompanied, or followed within 60 minutes, by headache.
# D. Not better accounted for by another ICHD-3 diagnosis.
#
# Based on 3 patient records

# %%
# Test with queries that SHOULD match your documents
specific_queries = [
    "Show me Document 1 content",
    "What does the first patient record say?",
    "Extract information from Document 2",
    "What medications are mentioned in the records?"
]

print("\n🧪 Testing with document-specific queries:")
for query in specific_queries:
    print(f"\n🔍 Query: {query}")
    answer, sources, mode = rag_answer_smart(query)
    print(f"Mode: {mode} | Similarity: {sources[0]['similarity']:.3f}")
    print(f"Answer: {answer[:200]}...")
# Out:
# 🧪 Testing with document-specific queries:
#
# 🔍 Query: Show me Document 1 content
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'Show me Document 1 content'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'Show me Document 1 content'
# Query embedding shape: (1, 384)
# Retrieved indices: [467 167 456]
# Distances: [1.7588716 1.7876325 1.8004951]
# Top result similarity score: 0.3625
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.3625
# 📊 Lowest similarity: 0.3571
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (521 characters)
# ============================================================
#
# Mode: rag_with_supplement | Similarity: 0.362
# Answer: Based on patient records:
# Document 1 discusses "Ischemic Stroke." It describes evidence of multiple acute cerebral infarctions, indicating ischemic damage to brain tissue, specifically noting tiny acu...
#
# 🔍 Query: What does the first patient record say?
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What does the first patient record say?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What does the first patient record say?'
# Query embedding shape: (1, 384)
# Retrieved indices: [314 111  89]
# Distances: [1.3125277 1.362578  1.384501 ]
# Top result similarity score: 0.4324
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.4324
# 📊 Lowest similarity: 0.4194
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (643 characters)
# ============================================================
#
# Mode: rag_with_supplement | Similarity: 0.432
# Answer: Based on patient records:
# The first patient record (Document 1) discusses information related to Asthma-COPD and Asthma. It states that a history of COPD may increase the probability of developing COP...
#
# 🔍 Query: Extract information from Document 2
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'Extract information from Document 2'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'Extract information from Document 2'
# Query embedding shape: (1, 384)
# Retrieved indices: [ 98 124 479]
# Distances: [1.7802901 1.7934365 1.8262864]
# Top result similarity score: 0.3597
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.3597
# 📊 Lowest similarity: 0.3538
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (501 characters)
# ============================================================
#
# Mode: rag_with_supplement | Similarity: 0.360
# Answer: Based on patient records:
# Document 2 contains the following information:
# *   **UA (Unstable Angina)**: Severe chest pain is a symbol of ACS-UA. The patient is a pleasant male who was previously health...
#
# 🔍 Query: What medications are mentioned in the records?
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What medications are mentioned in the records?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What medications are mentioned in the records?'
# Query embedding shape: (1, 384)
# Retrieved indices: [260 371 125]
# Distances: [1.2414856 1.2902434 1.3317498]
# Top result similarity score: 0.4461
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.4461
# 📊 Lowest similarity: 0.4289
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (156 characters)
# ============================================================
#
# Mode: rag_with_supplement | Similarity: 0.446
# Answer: Based on patient records:
# The following medications are mentioned:
# *   Fludrocortisone (Document 1)
# *   Hydrocortisone (Document 1)
# *   Aspirin (Document 3)...

# %%
import pickle
import numpy as np
import faiss

# Save documents
with open('documents.pkl', 'wb') as f:
    pickle.dump(documents, f)

# Save embeddings
np.save('embeddings.npy', embeddings)

# Save FAISS index
faiss.write_index(index, 'faiss_index.faiss')

print("✅ Documents, embeddings, and index saved!")
# Out:
# ✅ Documents, embeddings, and index saved!

# %%
def test_retrieval(query, expected_keywords, top_k=3):
    """Test if retrieval finds documents with specific keywords"""
    results = retrieve_with_scores(query, top_k=top_k)

    print(f"\n🔍 Query: '{query}'")
    print(f"📊 Retrieved {len(results)} documents")

    for i, r in enumerate(results):
        doc_text = r['document'].lower()
        found_keywords = [kw for kw in expected_keywords if kw in doc_text]

        print(f"\nDocument {i+1} (Similarity: {r['similarity']:.3f}):")
        print(f"  Contains keywords: {found_keywords}")
        print(f"  Preview: {doc_text[:100]}...")

    return results

# Test with known queries
test_cases = [
    ("migraine", ["migraine", "aura", "headache"]),
    ("heart condition", ["heart", "cardiac", "hypertension"]),
    ("medication", ["aspirin", "drug", "prescription"])
]

for query, keywords in test_cases:
    test_retrieval(query, keywords)
# Out:
# Query: 'migraine'
# Query embedding shape: (1, 384)
# Retrieved indices: [0 1 2]
# Distances: [0.59528196 0.6474576  0.6938983 ]
# Top result similarity score: 0.6268
#
# 🔍 Query: 'migraine'
# 📊 Retrieved 3 documents
#
# Document 1 (Similarity: 0.627):
#   Contains keywords: ['migraine', 'aura', 'headache']
#   Preview: "migraine with aura":"difficulty expressing language may be associated with migraine, especially whe...
#
# Document 2 (Similarity: 0.607):
#   Contains keywords: ['migraine', 'aura']
#   Preview: "migraine with aura":"chills or rigors may be part of a migraine aura, reflecting changes in the aut...
#
# Document 3 (Similarity: 0.590):
#   Contains keywords: ['migraine', 'aura', 'headache']
#   Preview: "migraine with aura":"blurred vision can be one of the visual symptoms associated with migraines, ca...
# Query: 'heart condition'
# Query embedding shape: (1, 384)
# Retrieved indices: [102 428  85]
# Distances: [0.8819189  0.9011301  0.90323806]
# Top result similarity score: 0.5314
#
# 🔍 Query: 'heart condition'
# 📊 Retrieved 3 documents
#
# Document 1 (Similarity: 0.531):
#   Contains keywords: ['heart', 'cardiac', 'hypertension']
#   Preview: "nste-acs":"st-elevations is a symotom of acs-stemi":"post-pci ekg demonstrated improvement in st-el...
#
# Document 2 (Similarity: 0.526):
#   Contains keywords: ['heart', 'cardiac', 'hypertension']
#   Preview: "hfpef":"lvef\u226550% is the critiera for hfpef":"lvef>55%: }, "heart failure":"cardiac structural ...
#
# Document 3 (Similarity: 0.525):
#   Contains keywords: ['heart', 'hypertension']
#   Preview: "nstemi":"high hs-ctn is a strong value for acs(> 0.2 \u03bcg/l\uff09":"he was noted to have ecg wit...
# Query: 'medication'
# Query embedding shape: (1, 384)
# Retrieved indices: [360 371 241]
# Distances: [1.391628  1.4019909 1.415248 ]
# Top result similarity score: 0.4181
#
# 🔍 Query: 'medication'
# 📊 Retrieved 3 documents
#
# Document 1 (Similarity: 0.418):
#   Contains keywords: []
#   Preview: "alzheimer":"the patient's alzheimer's disease was moderate":"moderate alzheimer's dementia: }, "sus...
#
# Document 2 (Similarity: 0.416):
#   Contains keywords: []
#   Preview: "epilepsy":"non-epileptic seizures usually do not affect the ecg, ruling out epilepsy":"ecg is norma...
#
# Document 3 (Similarity: 0.414):
#   Contains keywords: ['drug']
#   Preview: "hypertension":"an elevation of bp(sbp\u2265140mmhg or dbp\u226590mmhg)confirmed is a diagnostic cri...

# %%
# ================ 1. FIRST DEFINE EVALUATION FUNCTION ================
def evaluate_rag_triplet(query, answer, sources, ground_truth=None):
    """
    Evaluate RAG output on three metrics:
    1. Accuracy - Factual correctness
    2. Coherence - Logical flow and readability
    3. Relevance - Connection to query and sources
    """

    evaluation = {}

    # 1. ACCURACY SCORE (0-1)
    accuracy_score = 0.0

    # Rule-based accuracy checks
    accuracy_checks = []
    accuracy_checks.append(0.2 if "not a doctor" in answer.lower() or "information only" in answer.lower() else 0)
    accuracy_checks.append(0.2 if not any(word in answer.lower() for word in ["always", "never", "definitely", "guaranteed"]) else 0)
    accuracy_checks.append(0.2 if ("document" in answer.lower() or "source" in answer.lower()) else 0)
    accuracy_checks.append(0.2 if any(word in answer.lower() for word in ["may", "can", "sometimes", "often"]) else 0)
    accuracy_checks.append(0.2 if "cure" not in answer.lower() and "diagnose" not in answer.lower() else 0)

    accuracy_score = sum(accuracy_checks)

    # If ground truth provided, compare
    if ground_truth:
        answer_words = set(answer.lower().split())
        truth_words = set(ground_truth.lower().split())
        overlap = len(answer_words.intersection(truth_words)) / max(len(truth_words), 1)
        accuracy_score = max(accuracy_score, overlap)

    evaluation['accuracy'] = round(min(accuracy_score, 1.0), 3)

    # 2. COHERENCE SCORE (0-1)
    coherence_checks = []
    coherence_checks.append(0.25 if any(marker in answer for marker in ["•", "-", "1.", "2.", "**", "\n\n"]) else 0)
    coherence_checks.append(0.25 if 100 <= len(answer) <= 2000 else 0)
    coherence_checks.append(0.25 if answer.count('.') >= 2 else 0)
    coherence_checks.append(0.25 if answer.count('\n\n') >= 1 else 0)

    coherence_score = sum(coherence_checks)
    evaluation['coherence'] = round(min(coherence_score, 1.0), 3)

    # 3. RELEVANCE SCORE (0-1)
    relevance_score = 0.0

    if sources:
        top_sources = sources[:min(3, len(sources))]
        doc_relevance = sum(s['similarity'] for s in top_sources) / len(top_sources)

        query_words = set(query.lower().split())
        answer_words = set(answer.lower().split())
        word_overlap = len(query_words.intersection(answer_words)) / max(len(query_words), 1)

        relevance_score = 0.6 * doc_relevance + 0.4 * min(word_overlap, 1.0)
    else:
        query_keywords = ["what", "how", "when", "where", "why", "explain", "describe", "list"]
        if any(kw in query.lower() for kw in query_keywords) and len(answer) > 50:
            relevance_score = 0.5

    evaluation['relevance'] = round(min(relevance_score, 1.0), 3)

    # OVERALL SCORE
    evaluation['overall'] = round(
        0.4 * evaluation['accuracy'] +
        0.3 * evaluation['coherence'] +
        0.3 * evaluation['relevance'], 3
    )

    return evaluation


# ================ 2. THEN DEFINE BATCH EVALUATION ================
def batch_evaluate_rag_smart(test_queries, ground_truth_dict=None):
    """Evaluate multiple queries using SMART RAG"""

    results = []

    print("📊 SMART RAG EVALUATION RESULTS")
    print("="*70)
    print(f"{'Query':<40} {'Accuracy':<10} {'Coherence':<10} {'Relevance':<10} {'Overall':<10}")
    print("-"*70)

    for query in test_queries:
        # Get SMART RAG answer
        answer, sources, mode = rag_answer_smart(query)

        # Get ground truth if available
        ground_truth = ground_truth_dict.get(query) if ground_truth_dict else None

        # Evaluate using the function defined above
        eval_result = evaluate_rag_triplet(query, answer, sources, ground_truth)

        # Store results
        result = {
            'query': query,
            'answer': answer[:100] + "..." if len(answer) > 100 else answer,
            'sources_used': len(sources),
            'top_similarity': sources[0]['similarity'] if sources else 0,
            'mode': mode,
            **eval_result
        }
        results.append(result)

        # Print row
        print(f"{query[:37]:<37}... {eval_result['accuracy']:<10.3f} {eval_result['coherence']:<10.3f} "
              f"{eval_result['relevance']:<10.3f} {eval_result['overall']:<10.3f}")

    print("="*70)

    # Calculate averages
    if results:
        avg_accuracy = sum(r['accuracy'] for r in results) / len(results)
        avg_coherence = sum(r['coherence'] for r in results) / len(results)
        avg_relevance = sum(r['relevance'] for r in results) / len(results)
        avg_overall = sum(r['overall'] for r in results) / len(results)

        print(f"\n📈 AVERAGES:")
        print(f"Accuracy:  {avg_accuracy:.3f}")
        print(f"Coherence: {avg_coherence:.3f}")
        print(f"Relevance: {avg_relevance:.3f}")
        print(f"Overall:   {avg_overall:.3f}")

        # Show mode distribution
        modes = [r['mode'] for r in results]
        mode_counts = {mode: modes.count(mode) for mode in set(modes)}
        print(f"\n🎯 MODE USAGE:")
        for mode, count in mode_counts.items():
            print(f"  {mode}: {count} queries")

    return results


# ================ 3. TEST DATA ================
test_queries = [
    "What is migraine with aura?",
    "What heart conditions are mentioned in records?",
    "Describe patient symptoms",
    "What medications are used?"
]

ground_truth_examples = {
    "What is migraine with aura?": "Migraine with aura involves neurological symptoms before headache including visual disturbances.",
    "What heart conditions are mentioned in records?": "Heart conditions may include coronary artery disease, heart failure, or hypertension.",
}


# ================ 4. RUN EVALUATION ================
print("🧪 Evaluating SMART RAG System...")
evaluation_results = batch_evaluate_rag_smart(test_queries, ground_truth_examples)

# ================ 5. SHOW DETAILED RESULTS ================
print("\n🔍 DETAILED RESULTS:")
for result in evaluation_results:
    print(f"\nQuery: {result['query']}")
    print(f"Mode: {result['mode']}")
    print(f"Answer preview: {result['answer']}")
    print(f"Sources: {result['sources_used']}, Top similarity: {result['top_similarity']:.3f}")
    print(f"Scores - Accuracy: {result['accuracy']:.3f}, Coherence: {result['coherence']:.3f}, "
          f"Relevance: {result['relevance']:.3f}, Overall: {result['overall']:.3f}")
# Out:
# 🧪 Evaluating SMART RAG System...
# 📊 SMART RAG EVALUATION RESULTS
# ======================================================================
# Query                                    Accuracy   Coherence  Relevance  Overall
# ----------------------------------------------------------------------
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What is migraine with aura?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What is migraine with aura?'
# Query embedding shape: (1, 384)
# Retrieved indices: [2 0 3]
# Distances: [0.6261587  0.63675845 0.6846194 ]
# Top result similarity score: 0.6149
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.6149
# 📊 Lowest similarity: 0.5936
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (775 characters)
# ============================================================
#
# What is migraine with aura?          ... 0.800      1.000      0.604      0.801
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What heart conditions are mentioned in records?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What heart conditions are mentioned in records?'
# Query embedding shape: (1, 384)
# Retrieved indices: [103 422  21]
# Distances: [0.95762384 0.9728943  0.97672737]
# Top result similarity score: 0.5108
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.5108
# 📊 Lowest similarity: 0.5059
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (773 characters)
# ============================================================
#
# What heart conditions are mentioned i... 0.600      0.750      0.419      0.591
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'Describe patient symptoms'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'Describe patient symptoms'
# Query embedding shape: (1, 384)
# Retrieved indices: [183 175  87]
# Distances: [1.0532335 1.0596795 1.0737114]
# Top result similarity score: 0.487
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.4870
# 📊 Lowest similarity: 0.4822
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (731 characters)
# ============================================================
#
# Describe patient symptoms            ... 0.800      0.750      0.558      0.712
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What medications are used?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What medications are used?'
# Query embedding shape: (1, 384)
# Retrieved indices: [260 208 371]
# Distances: [1.3101592 1.3492517 1.3632109]
# Top result similarity score: 0.4329
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.4329
# 📊 Lowest similarity: 0.4232
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (220 characters)
# ============================================================
#
# What medications are used?           ... 0.800      0.250      0.356      0.502
# ======================================================================
#
# 📈 AVERAGES:
# Accuracy:  0.750
# Coherence: 0.688
# Relevance: 0.484
# Overall:   0.651
#
# 🎯 MODE USAGE:
#   rag_with_supplement: 4 queries
#
# 🔍 DETAILED RESULTS:
#
# Query: What is migraine with aura?
# Mode: rag_with_supplement
# Answer preview: Based on patient records:
# Migraine with aura is characterized by specific neurological symptoms that...
# Sources: 3, Top similarity: 0.615
# Scores - Accuracy: 0.800, Coherence: 1.000, Relevance: 0.604, Overall: 0.801
#
# Query: What heart conditions are mentioned in records?
# Mode: rag_with_supplement
# Answer preview: Based on patient records:
# The patient records mention several heart conditions:
#
# *   **Non-ST-Elevat...
# Sources: 3, Top similarity: 0.511
# Scores - Accuracy: 0.600, Coherence: 0.750, Relevance: 0.419, Overall: 0.591
#
# Query: Describe patient symptoms
# Mode: rag_with_supplement
# Answer preview: Based on patient records:
# The patient experienced a dull chest pain, diaphoresis, and a clammy feeli...
# Sources: 3, Top similarity: 0.487
# Scores - Accuracy: 0.800, Coherence: 0.750, Relevance: 0.558, Overall: 0.712
#
# Query: What medications are used?
# Mode: rag_with_supplement
# Answer preview: Based on patient records:
# The patient's records indicate that fludrocortisone and hydrocortisone are...
# Sources: 3, Top similarity: 0.433
# Scores - Accuracy: 0.800, Coherence: 0.250, Relevance: 0.356, Overall: 0.502

# %%
def analyze_rag_errors_fixed(test_queries):
    """Deep dive into potential errors and limitations - FIXED VERSION"""

    print("🔍 RAG ERROR ANALYSIS (FIXED)")
    print("="*70)

    error_categories = {
        'retrieval_errors': [],
        'generation_errors': [],
        'medical_safety_errors': [],
        'formatting_issues': []
    }

    for query in test_queries:
        print(f"\n{'='*60}")
        print(f"Analyzing: '{query}'")

        # ✅ FIXED: Get all 3 values from rag_answer_smart
        answer, sources, mode = rag_answer_smart(query)

        print(f"Mode used: {mode}")

        # 1. RETRIEVAL ERROR ANALYSIS
        print("\n📊 RETRIEVAL ANALYSIS:")
        if not sources:
            print("❌ CRITICAL: No documents retrieved")
            error_categories['retrieval_errors'].append(query)
        else:
            print(f"✅ Documents retrieved: {len(sources)}")

            # Check similarity distribution
            sim_scores = [s['similarity'] for s in sources]
            print(f"   Similarity range: {min(sim_scores):.3f} - {max(sim_scores):.3f}")

            if max(sim_scores) < 0.3:
                print("⚠️ WARNING: Low similarity scores (< 0.3)")
                error_categories['retrieval_errors'].append(f"{query} - low similarity")

        # 2. GENERATION ERROR ANALYSIS
        print("\n🤖 GENERATION ANALYSIS:")

        # Check for hallucinations
        if sources and len(sources) > 0:
            # Extract document keywords
            doc_keywords = set()
            for s in sources[:2]:
                doc_text = s['document'].lower()
                doc_keywords.update(doc_text.split()[:20])

            # Check if answer introduces new concepts
            answer_words = set(answer.lower().split())
            new_words = answer_words - doc_keywords

            medical_terms = ["treat", "cure", "diagnose", "prescribe", "recommend"]
            if any(term in answer.lower() for term in medical_terms):
                print("⚠️ WARNING: Potential medical advice/hallucination")
                error_categories['medical_safety_errors'].append(query)

        # Check for "not found" patterns
        not_found_phrases = ["not found", "no information", "not available", "does not contain"]
        if any(phrase in answer.lower() for phrase in not_found_phrases):
            print("⚠️ NOTE: Answer indicates missing information")

        # 3. FORMATTING ANALYSIS
        print("\n📝 FORMATTING ANALYSIS:")

        # Check length
        if len(answer) < 100:
            print("⚠️ WARNING: Answer very short (< 100 chars)")
            error_categories['formatting_issues'].append(f"{query} - too short")
        elif len(answer) > 1000:
            print("⚠️ NOTE: Answer very long (> 1000 chars)")

        # Check citations
        if "document" not in answer.lower() and "source" not in answer.lower():
            print("⚠️ WARNING: No document citations found")
            error_categories['formatting_issues'].append(f"{query} - no citations")

        # Check structure
        if not any(marker in answer for marker in ["•", "-", "\n", "1.", "2."]):
            print("⚠️ NOTE: Answer lacks structured formatting")

    # SUMMARY
    print(f"\n{'='*70}")
    print("📋 ERROR SUMMARY")
    print("="*70)

    total_errors = sum(len(errors) for errors in error_categories.values())

    for category, errors in error_categories.items():
        print(f"\n{category.upper().replace('_', ' ')}:")
        if errors:
            for error in errors:
                print(f"  ⚠️ {error}")
        else:
            print("  ✅ No issues detected")

    print(f"\n📊 TOTAL ERRORS FOUND: {total_errors}")

    if total_errors == 0:
        print("🎉 EXCELLENT: No significant errors detected!")
    elif total_errors <= 3:
        print("✅ GOOD: Minor issues only")
    else:
        print("⚠️ NEEDS ATTENTION: Multiple issues detected")

    return error_categories

# Run the FIXED error analysis
print("🧪 Starting Fixed Error Analysis...")
errors = analyze_rag_errors_fixed(test_queries)
# Out:
# 🧪 Starting Fixed Error Analysis...
# 🔍 RAG ERROR ANALYSIS (FIXED)
# ======================================================================
#
# ============================================================
# Analyzing: 'What is migraine with aura?'
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What is migraine with aura?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What is migraine with aura?'
# Query embedding shape: (1, 384)
# Retrieved indices: [2 0 3]
# Distances: [0.6261587  0.63675845 0.6846194 ]
# Top result similarity score: 0.6149
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.6149
# 📊 Lowest similarity: 0.5936
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (2007 characters)
# ============================================================
#
# Mode used: rag_with_supplement
#
# 📊 RETRIEVAL ANALYSIS:
# ✅ Documents retrieved: 3
#    Similarity range: 0.594 - 0.615
#
# 🤖 GENERATION ANALYSIS:
#
# 📝 FORMATTING ANALYSIS:
# ⚠️ NOTE: Answer very long (> 1000 chars)
#
# ============================================================
# Analyzing: 'What heart conditions are mentioned in records?'
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What heart conditions are mentioned in records?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What heart conditions are mentioned in records?'
# Query embedding shape: (1, 384)
# Retrieved indices: [103 422  21]
# Distances: [0.95762384 0.9728943  0.97672737]
# Top result similarity score: 0.5108
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.5108
# 📊 Lowest similarity: 0.5059
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (538 characters)
# ============================================================
#
# Mode used: rag_with_supplement
#
# 📊 RETRIEVAL ANALYSIS:
# ✅ Documents retrieved: 3
#    Similarity range: 0.506 - 0.511
#
# 🤖 GENERATION ANALYSIS:
#
# 📝 FORMATTING ANALYSIS:
#
# ============================================================
# Analyzing: 'Describe patient symptoms'
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'Describe patient symptoms'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'Describe patient symptoms'
# Query embedding shape: (1, 384)
# Retrieved indices: [183 175  87]
# Distances: [1.0532335 1.0596795 1.0737114]
# Top result similarity score: 0.487
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.4870
# 📊 Lowest similarity: 0.4822
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (335 characters)
# ============================================================
#
# Mode used: rag_with_supplement
#
# 📊 RETRIEVAL ANALYSIS:
# ✅ Documents retrieved: 3
#    Similarity range: 0.482 - 0.487
#
# 🤖 GENERATION ANALYSIS:
#
# 📝 FORMATTING ANALYSIS:
#
# ============================================================
# Analyzing: 'What medications are used?'
#
# ============================================================
# 🤖 SMART RAG Pipeline Started
# 📝 Query: 'What medications are used?'
# 🔍 Retrieving top 3 most relevant documents...
# Query: 'What medications are used?'
# Query embedding shape: (1, 384)
# Retrieved indices: [260 208 371]
# Distances: [1.3101592 1.3492517 1.3632109]
# Top result similarity score: 0.4329
# 📄 Documents retrieved: 3
# 📊 Highest similarity: 0.4329
# 📊 Lowest similarity: 0.4232
# ✅ Found relevant documents - using RAG with supplementation
# 📋 Context prepared: 3 documents
# 📏 Total context length: 1615 characters
# 💭 Generating response (rag_with_supplement)...
# ✅ Response generated successfully (180 characters)
# ============================================================
#
# Mode used: rag_with_supplement
#
# 📊 RETRIEVAL ANALYSIS:
# ✅ Documents retrieved: 3
#    Similarity range: 0.423 - 0.433
#
# 🤖 GENERATION ANALYSIS:
# ⚠️ WARNING: Potential medical advice/hallucination
#
# 📝 FORMATTING ANALYSIS:
#
# ======================================================================
# 📋 ERROR SUMMARY
# ======================================================================
#
# RETRIEVAL ERRORS:
#   ✅ No issues detected
#
# GENERATION ERRORS:
#   ✅ No issues detected
#
# MEDICAL SAFETY ERRORS:
#   ⚠️ What medications are used?
#
# FORMATTING ISSUES:
#   ✅ No issues detected
#
# 📊 TOTAL ERRORS FOUND: 1
# ✅ GOOD: Minor issues only
